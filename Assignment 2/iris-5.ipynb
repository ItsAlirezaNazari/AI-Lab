# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsAlirezaNazari/AI-Lab/blob/main/Assignment%202/iris-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
sns.histplot(data=iris, x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>
