# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsAlirezaNazari/AI-Lab/blob/main/Assignment%202/iris-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
sns.barplot(iris, x="petal_length", y="sepal_length")
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>
